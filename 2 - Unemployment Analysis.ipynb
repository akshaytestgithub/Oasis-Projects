# %% [markdown]
# # Unemployment Analysis

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset

# %%
data = pd.read_csv('Unemployment in India.csv')
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %% [markdown]
# # Data Preprocessing

# %%
data.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
data.tail()
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
data.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
data.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
data = data[:740]
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 735     Uttarakhand   29-02-2020    Monthly                              5.28
# 736     Uttarakhand   31-03-2020    Monthly                              8.15
# 737     Uttarakhand   30-04-2020    Monthly                             13.18
# 738     Uttarakhand   31-05-2020    Monthly                             17.36
# 739     Uttarakhand   30-06-2020    Monthly                              5.08
#
# ...

# %%
data.Region.unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', nan, 'Chandigarh'],
#       dtype=object)

# %%
data[' Date'].unique()
# Out:
# array([' 31-05-2019', ' 30-06-2019', ' 31-07-2019', ' 31-08-2019',
#        ' 30-09-2019', ' 31-10-2019', ' 30-11-2019', ' 31-12-2019',
#        ' 31-01-2020', ' 29-02-2020', ' 31-03-2020', ' 30-04-2020',
#        ' 31-05-2020', ' 30-06-2020', nan], dtype=object)

# %%
data.mean()
# Out:
# C:\Users\MY-PC\AppData\Local\Temp/ipykernel_4500/531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
#  Estimated Unemployment Rate (%)            1.184793e+01
#  Estimated Employed                         7.138850e+06
#  Estimated Labour Participation Rate (%)    4.260964e+01
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\MY-PC\AppData\Local\Temp/ipykernel_4500/4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
#  Estimated Unemployment Rate (%)                  8.445
#  Estimated Employed                         4642576.000
#  Estimated Labour Participation Rate (%)         41.095
# dtype: float64

# %%
data.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        726.000000         7.260000e+02
# mean                          11.847934         7.138850e+06
# std                           10.808248         8.151027e+06
# min                            0.000000         4.942000e+04
# 25%                            4.617500         1.159423e+06
# 50%                            8.445000         4.642576e+06
# 75%                           15.995000         1.129481e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                726.000000
# mean                                  42.609642
# std                                    8.180703
# min                                   13.330000
# 25%                                   38.015000
# 50%                                   41.095000
# 75%                                   45.475000
# ...

# %%
data.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
data.rename(columns = {'Region':'Region', 'Date':'Date', 'Frequency':'Frequency', 'Estimated Unemployment Rate(%)':'Estimated Unemployment Rate in %', 'Estimated Employed':'Estimated Employed', 'Estimated Labour Participation Rate (%)':'Estimated Labour Participation Rate (%)', 'Area':'Area'}, inplace = True)
data
# Out:
# C:\Users\MY-PC\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 735     Uttarakhand   29-02-2020    Monthly                              5.28
# ...

# %%
print(data.columns.tolist())
# Out:
# ['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)', 'Area']

# %%
data['Region']
# Out:
# 0      Andhra Pradesh
# 1      Andhra Pradesh
# 2      Andhra Pradesh
# 3      Andhra Pradesh
# 4      Andhra Pradesh
#             ...
# 735       Uttarakhand
# 736       Uttarakhand
# 737       Uttarakhand
# 738       Uttarakhand
# 739       Uttarakhand
# Name: Region, Length: 740, dtype: object

# %%
data.corr()
# Out:
#                                            Estimated Unemployment Rate (%)  \
#  Estimated Unemployment Rate (%)                                  1.000000
#  Estimated Employed                                              -0.220845
#  Estimated Labour Participation Rate (%)                          0.004222
#
#                                            Estimated Employed  \
#  Estimated Unemployment Rate (%)                    -0.220845
#  Estimated Employed                                  1.000000
#  Estimated Labour Participation Rate (%)             0.009746
#
#                                            Estimated Labour Participation Rate (%)
#  Estimated Unemployment Rate (%)                                          0.004222
#  Estimated Employed                                                       0.009746
#  Estimated Labour Participation Rate (%)                                  1.000000

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(12,8))
sns.countplot(data['Region'])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('States', fontsize=12)
plt.title('Count the states', fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\MY-PC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
grouped_df = data.groupby(["Region"])[" Estimated Unemployment Rate (%)"].aggregate("mean").reset_index()

plt.figure(figsize=(12,8))
sns.pointplot(grouped_df['Region'].values, grouped_df[' Estimated Unemployment Rate (%)'].values, alpha=0.8, color=color[2])
plt.ylabel(' rate', fontsize=12)
plt.xlabel('Region', fontsize=12)
plt.title("Average of mean", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\MY-PC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(x = data['Area'], y = data[' Estimated Unemployment Rate (%)'], kind = 'scatter')
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
sns.heatmap(data.corr(), annot = True, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
print(data.columns.tolist())

# %%
plt.figure(figsize=(18,10))
sns.barplot(x = 'Region', y = ' Estimated Unemployment Rate (%)', data = data)
plt.ylabel(' rate', fontsize=12)
plt.xlabel('Region', fontsize=12)
plt.title("Unemployment Rate in Region", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.barplot(x = 'Region', y = ' Estimated Employed', data = data)
plt.ylabel(' rate', fontsize=12)
plt.xlabel('Region', fontsize=12)
plt.title("Estimates Employed in Region", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.boxplot(y = data[' Estimated Unemployment Rate (%)'], x = data[' Date'])
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.boxplot(y = data[' Estimated Employed'], x = data[' Date'])
plt.xticks(rotation='vertical')
plt.show()
