# %% [markdown]
# # Sales Prediction

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset

# %%
data = pd.read_csv('Advertising.csv')
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# # Data Preprocessing

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.mean()
# Out:
# Unnamed: 0    100.5000
# TV            147.0425
# Radio          23.2640
# Newspaper      30.5540
# Sales          14.0225
# dtype: float64

# %%
data.median()
# Out:
# Unnamed: 0    100.50
# TV            149.75
# Radio          22.90
# Newspaper      25.75
# Sales          12.90
# dtype: float64

# %%
df = data.sort_values(by = 'Sales')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 130         131    0.7   39.6        8.7    1.6
# 155         156    4.1   11.6        5.7    3.2
# 8             9    8.6    2.1        1.0    4.8
# 108         109   13.1    0.4       25.6    5.3
# 78           79    5.4   29.9        9.4    5.3
# ..          ...    ...    ...        ...    ...
# 98           99  289.7   42.3       51.2   25.4
# 147         148  243.2   49.0       44.3   25.4
# 198         199  283.6   42.0       66.2   25.5
# 183         184  287.6   43.0       71.8   26.2
# 175         176  276.9   48.9       41.8   27.0
#
# [200 rows x 5 columns]

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data.describe().T
# Out:
#             count      mean        std  min     25%     50%      75%    max
# Unnamed: 0  200.0  100.5000  57.879185  1.0  50.750  100.50  150.250  200.0
# TV          200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Radio       200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# Newspaper   200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# Sales       200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (25,9))
plt.plot(data)
plt.show()

# %%
sns.jointplot(x = data['TV'], y = data['Sales'], kind = 'scatter', color = 'green')
plt.show()

# %%
sns.jointplot(x = data['Radio'], y = data['Sales'], kind = 'scatter')
plt.show()

# %%
sns.jointplot(x = data['Newspaper'], y = data['Sales'], kind = 'scatter', color = 'brown')
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
sns.heatmap(data.corr(), annot = True, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Building

# %%
x = data.iloc[:, :-1]
x
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
y = data.iloc[:, -1]
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state = 20, test_size = 0.2)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (160, 4)
# (160,)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)
pred
# Out:
# array([18.15059189, 19.32848413,  8.95874461, 15.7406192 , 19.47530221,
#        17.10411079, 12.08724864,  8.12198441, 21.62211919,  5.43006563,
#        11.57540505, 13.85880206, 16.91282692, 10.9595728 , 20.7234466 ,
#        24.55801106,  5.43898176, 13.20173898,  8.09225739,  4.60673688,
#        19.74240894, 16.26775327, 17.06506599, 23.11902859, 20.62078299,
#         8.82484256, 14.91249009, 10.84144464, 12.92285983, 15.28421161,
#         7.69045054, 19.52567171,  9.19091323, 10.57730963, 23.95630442,
#        15.2385924 ,  9.93689376,  9.05667528, 11.71030057, 13.77830121])

# %%
# Comparing sales 
compare = pd.DataFrame({'y_test':list(y_test), 'pred':list(pred)})
compare.head()
# Out:
#    y_test       pred
# 0    16.1  18.150592
# 1    18.9  19.328484
# 2     9.7   8.958745
# 3    11.8  15.740619
# 4    19.8  19.475302

# %%
sns.jointplot(x = y_test, y = pred, kind = 'scatter', color = 'orange')
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
from sklearn import metrics 
mae = metrics.mean_absolute_error(y_test, pred)
print('Mean absolute error : {}'.format(mae))
# Out:
# Mean absolute error : 1.419538198979992

# %%
mse = metrics.mean_squared_error(y_test, pred)
print('Mean square error : {}'.format(mse))
# Out:
# Mean square error : 3.51544071910545

# %%
r2 = metrics.r2_score(y_test, pred)
print('R2 Square : {}'.format(r2))
# Out:
# R2 Square : 0.9028631545455049
